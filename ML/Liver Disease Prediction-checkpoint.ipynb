# %% [markdown]
# # Liver Disease Prediction

# %% [raw]
# # Name: Md Saiful Islam (ID:1721648642) ,saiful.islam5@northsouth.edu ,Mobile Number:01624365646

# %% [markdown]
# #Md. Riajul Alam Khan - 1713098642 , riajul.khan@northsouth.edu ,Mobile Number: 01871730301

# %% [markdown]
# #Syed Sakib-Ur-Rahman - 1712265642 - syed.rahman03@northsouth.edu - 01670058632

# %% [markdown]
# #Shuvo Jyoti Das – 1721786042 - shuvojyoti.das@northsouth.edu ,Mobile Number: 01622724021

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
from sklearn import tree

# %%
patients=pd.read_csv("indian_liver_patient.csv")

# %%
patients.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
patients.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
patients.isnull().any()
# Out:
# Age                           False
# Gender                        False
# Total_Bilirubin               False
# Direct_Bilirubin              False
# Alkaline_Phosphotase          False
# Alamine_Aminotransferase      False
# Aspartate_Aminotransferase    False
# Total_Protiens                False
# Albumin                       False
# Albumin_and_Globulin_Ratio     True
# Dataset                       False
# dtype: bool

# %%
nan_raws=patients[patients['Albumin_and_Globulin_Ratio'].isnull()]

# %%
print(nan_raws)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 209   45  Female              0.9               0.3                   189
# 241   51    Male              0.8               0.2                   230
# 253   35  Female              0.6               0.2                   180
# 312   27    Male              1.3               0.6                   106
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 209                        23                          33             6.6
# 241                        24                          46             6.5
# 253                        12                          15             5.2
# 312                        25                          54             8.5
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 209      3.9                         NaN        1
# 241      3.1                         NaN        1
# 253      2.7                         NaN        2
# ...

# %%
patients['Dataset'].value_counts()
# Out:
# 1    416
# 2    167
# Name: Dataset, dtype: int64

# %%
patients=patients.dropna()

# %%
patients.isnull().any()
# Out:
# Age                           False
# Gender                        False
# Total_Bilirubin               False
# Direct_Bilirubin              False
# Alkaline_Phosphotase          False
# Alamine_Aminotransferase      False
# Aspartate_Aminotransferase    False
# Total_Protiens                False
# Albumin                       False
# Albumin_and_Globulin_Ratio    False
# Dataset                       False
# dtype: bool

# %%
patients.shape
# Out:
# (579, 11)

# %%
X=patients.iloc[:,0:10]

# %%
X.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio
# 0      3.3                        0.90
# ...

# %%
y=patients.iloc[:,-1]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Dataset, dtype: int64

# %%
X.Gender= X.Gender.map({'Male':0,'Female':1})

# %%
X.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       1              0.7               0.1                   187
# 1   62       0             10.9               5.5                   699
# 2   62       0              7.3               4.1                   490
# 3   58       0              1.0               0.4                   182
# 4   72       0              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio
# 0      3.3                        0.90
# ...

# %%
patients.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Total_Bilirubin'}>,
#         <AxesSubplot:title={'center':'Direct_Bilirubin'}>],
#        [<AxesSubplot:title={'center':'Alkaline_Phosphotase'}>,
#         <AxesSubplot:title={'center':'Alamine_Aminotransferase'}>,
#         <AxesSubplot:title={'center':'Aspartate_Aminotransferase'}>],
#        [<AxesSubplot:title={'center':'Total_Protiens'}>,
#         <AxesSubplot:title={'center':'Albumin'}>,
#         <AxesSubplot:title={'center':'Albumin_and_Globulin_Ratio'}>],
#        [<AxesSubplot:title={'center':'Dataset'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Let's make the Gender column into numerical format:

# %%
patients.Gender=patients.Gender.map( {'Male':0 , 'Female':1} )
df_majority=patients[patients.Dataset==1]
df_minority= patients[patients.Dataset==2]

# %%
patients.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       1              0.7               0.1                   187
# 1   62       0             10.9               5.5                   699
# 2   62       0              7.3               4.1                   490
# 3   58       0              1.0               0.4                   182
# 4   72       0              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
patients['Gender'].value_counts().plot.bar(color='green')
plt.show()

# %%
patients['Dataset'].value_counts().plot.bar(color='black')
plt.show()

# %%
sns.pairplot(patients)
plt.show()

# %%
plt.figure(figsize=(8,6))
patients.groupby('Gender').sum()["Total_Protiens"].plot.bar(color='red')
plt.show()

# %% [markdown]
# protein intake is higher in the case of Male and comparitively less in females

# %%
plt.figure(figsize=(8,6))
patients.groupby('Gender').sum()['Albumin'].plot.bar(color='midnightblue')
plt.show()

# %% [markdown]
# Albumin Level is higher in the case in the case of male compared to female

# %%
plt.figure(figsize=(8,6))
patients.groupby('Gender').sum()['Total_Bilirubin'].plot.bar(color='slategray')
plt.show()

# %% [markdown]
# We can clearly see that males has more bilirubin content compared to female

# %% [markdown]
# # correlation

# %%
corr=patients.corr()

# %%
plt.figure(figsize=(15,15)) 
sns.heatmap(corr,cmap="YlGnBu",annot=True)
plt.show()

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
# Train the model using the training sets and check score
logreg.fit(X_train, y_train)
#Predict Output
log_predicted= logreg.predict(X_test)

logreg_score = round(logreg.score(X_train, y_train) * 100, 2)
logreg_score_test = round(logreg.score(X_test, y_test) * 100, 2)
#Equation coefficient and Intercept
print('Logistic Regression Training Score: \n', logreg_score)
print('Logistic Regression Test Score: \n', logreg_score_test)
print('Confusion Matrix: \n', confusion_matrix(y_test,log_predicted))
print('Classification Report: \n', classification_report(y_test,log_predicted))
print('Accuracy: \n', accuracy_score(y_test,log_predicted)*100)
#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(log_predicted, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('LogisticRegression')
plt.show()

metrics.plot_roc_curve(logreg,X_test,y_test)
plt.title('LogisticRegression')
plt.show()
# Out:
# Logistic Regression Training Score:
#  71.66
# Logistic Regression Test Score:
#  70.34
# Confusion Matrix:
#  [[95  9]
#  [34  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.74      0.91      0.82       104
#            2       0.44      0.17      0.25        41
#
#     accuracy                           0.70       145
#    macro avg       0.59      0.54      0.53       145
# weighted avg       0.65      0.70      0.65       145
#
# Accuracy:
#  70.34482758620689

# %% [markdown]
# # DecisionTreeClassifier

# %%
 from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()


#fiting the model
DT.fit(X_train, y_train)

#prediction
y_pred = DT.predict(X_test)

DT_score = round(DT.score(X_train, y_train) * 100, 2)
DT_score_test = round(DT.score(X_test, y_test) * 100, 2)

print('DecisionTreeClassifier Training Score: \n', DT_score)
print('DecisionTreeClassifier Test Score: \n', DT_score_test)
print('Confusion Matrix: \n', confusion_matrix(y_test,y_pred))
print('Classification Report: \n', classification_report(y_test,y_pred))

#Accuracy
print("Accuracy ", DT.score(X_test, y_test)*100)

#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('DecisionTreeClassifier')
plt.show()


plt.figure(figsize=(80,50))
tree.plot_tree(DT,filled=True,fontsize=100,max_depth=2)

metrics.plot_roc_curve(DT,X_test,y_test)
plt.title('DecisionTreeClassifier')
plt.show()
# Out:
# DecisionTreeClassifier Training Score:
#  100.0
# DecisionTreeClassifier Test Score:
#  60.69
# Confusion Matrix:
#  [[74 30]
#  [27 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.73      0.71      0.72       104
#            2       0.32      0.34      0.33        41
#
#     accuracy                           0.61       145
#    macro avg       0.53      0.53      0.53       145
# weighted avg       0.62      0.61      0.61       145
#
# Accuracy  60.689655172413794

# %% [markdown]
# # KNeighborsClassifier

# %%
import seaborn as sb
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 8)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)

#prediction
knn_pred =knn.predict(X_test)

knn_score = round(knn.score(X_train, y_train) * 100, 2)
knn_score_test = round(knn.score(X_test, y_test) * 100, 2)

print('KNeighborsClassifier Training Score: \n', knn_score)
print('KNeighborsClassifier Test Score: \n', knn_score_test)
print("Accuracy:", accuracy_score(y_test, knn_pred)*100)
print('Confusion Matrix: \n', confusion_matrix(y_test,knn_pred))
print('Classification Report: \n', classification_report(y_test,knn_pred))

print(confusion_matrix(y_test, knn_pred))
#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(knn_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('KNN')
plt.show()

metrics.plot_roc_curve(knn,X_test,y_test)
plt.title('KNN')
plt.show()
# Out:
# KNeighborsClassifier Training Score:
#  76.96
# KNeighborsClassifier Test Score:
#  67.59
# Accuracy: 67.58620689655173
# Confusion Matrix:
#  [[89 15]
#  [32  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.74      0.86      0.79       104
#            2       0.38      0.22      0.28        41
#
#     accuracy                           0.68       145
#    macro avg       0.56      0.54      0.53       145
# weighted avg       0.63      0.68      0.65       145
#
# [[89 15]
#  [32  9]]

# %% [markdown]
# # SVM Classifier

# %%
from sklearn.svm import SVC

# %%
pr= SVC(gamma='auto')
pr.fit(X_train, y_train)
pr_pred = pr.predict(X_test)

pr_score = round(pr.score(X_train, y_train) * 100, 2)
pr_score_test = round(pr.score(X_test, y_test) * 100, 2)


print('SVM Classifier Training Score: \n', pr_score)
print('SVM Classifier Test Score: \n', pr_score_test)
print("Accuracy: \n", accuracy_score(y_test, pr_pred)*100)
print('Confusion Matrix: \n', confusion_matrix(y_test,pr_pred))
print('Classification Report: \n', classification_report(y_test,pr_pred))
print(confusion_matrix(y_test, pr_pred))

#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(pr_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('svm Classifier')
plt.show()
metrics.plot_roc_curve(pr,X_test,y_test)
plt.title('svm Classifier')
plt.show()
# Out:
# SVM Classifier Training Score:
#  99.77
# SVM Classifier Test Score:
#  72.41
# Accuracy:
#  72.41379310344827
# Confusion Matrix:
#  [[104   0]
#  [ 40   1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.72      1.00      0.84       104
#            2       1.00      0.02      0.05        41
#
#     accuracy                           0.72       145
#    macro avg       0.86      0.51      0.44       145
# weighted avg       0.80      0.72      0.62       145
#
# [[104   0]
#  [ 40   1]]

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random=RandomForestClassifier()
random.fit(X_train, y_train)
random_pred = random.predict(X_test)

random_score = round(random.score(X_train, y_train) * 100, 2)
random_score_test = round(random.score(X_test, y_test) * 100, 2)

print('RandomForestClassifier Training Score: \n', pr_score)
print('RandomForestClassifier Test Score: \n', pr_score_test)
print("Accuracy:", accuracy_score(y_test, random_pred)*100, )
print('Confusion Matrix: \n', confusion_matrix(y_test,random_pred))
print('Classification Report: \n', classification_report(y_test,random_pred))
#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(random_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('RandomForestClassifier')
plt.show()
metrics.plot_roc_curve(random,X_test,y_test)
plt.title('RandomForestClassifier')
plt.show()
# Out:
# RandomForestClassifier Training Score:
#  99.77
# RandomForestClassifier Test Score:
#  72.41
# Accuracy: 67.58620689655173
# Confusion Matrix:
#  [[88 16]
#  [31 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.74      0.85      0.79       104
#            2       0.38      0.24      0.30        41
#
#     accuracy                           0.68       145
#    macro avg       0.56      0.55      0.54       145
# weighted avg       0.64      0.68      0.65       145

# %% [markdown]
# # upsampling

# %%
from pandas_profiling import ProfileReport

# %%
from sklearn.utils import resample

# %%
df_minority_upsamples= resample(df_minority,replace=True,n_samples=414,random_state=123)

# %%
df_upsampled=pd.concat([df_majority,df_minority_upsamples])

# %%
df_upsampled.Dataset.value_counts()
# Out:
# 2    414
# 1    414
# Name: Dataset, dtype: int64

# %%
X=df_upsampled.iloc[:,0:10]

# %%
y=df_upsampled.iloc[:,-1]

# %%
X.shape
# Out:
# (828, 10)

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
# Train the model using the training sets and check score
logreg.fit(X_train, y_train)
#Predict Output
log_predicted= logreg.predict(X_test)

logreg_score = round(logreg.score(X_train, y_train) * 100, 2)
logreg_score_test = round(logreg.score(X_test, y_test) * 100, 2)
#Equation coefficient and Intercept
print('Logistic Regression Training Score: \n', logreg_score)
print('Logistic Regression Test Score: \n', logreg_score_test)
print('Confusion Matrix: \n', confusion_matrix(y_test,log_predicted))
print('Classification Report: \n', classification_report(y_test,log_predicted))
print('Accuracy: \n', accuracy_score(y_test,log_predicted)*100)
#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(log_predicted, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('LogisticRegression')
plt.show()

metrics.plot_roc_curve(logreg,X_test,y_test)
plt.title('LogisticRegression')
plt.show()
# Out:
# Logistic Regression Training Score:
#  68.92
# Logistic Regression Test Score:
#  72.46
# Confusion Matrix:
#  [[70 39]
#  [18 80]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.80      0.64      0.71       109
#            2       0.67      0.82      0.74        98
#
#     accuracy                           0.72       207
#    macro avg       0.73      0.73      0.72       207
# weighted avg       0.74      0.72      0.72       207
#
# Accuracy:
#  72.46376811594203

# %% [markdown]
# # DecisionTreeClassifier

# %%
 from sklearn.tree import DecisionTreeClassifier

# %%
DT = DecisionTreeClassifier()


#fiting the model
DT.fit(X_train, y_train)

#prediction
y_pred = DT.predict(X_test)

DT_score = round(DT.score(X_train, y_train) * 100, 2)
DT_score_test = round(DT.score(X_test, y_test) * 100, 2)

print('DecisionTreeClassifier Training Score: \n', DT_score)
print('DecisionTreeClassifier Test Score: \n', DT_score_test)
print('Confusion Matrix: \n', confusion_matrix(y_test,y_pred))
print('Classification Report: \n', classification_report(y_test,y_pred))

#Accuracy
print("Accuracy ", DT.score(X_test, y_test)*100)

#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(y_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('DecisionTreeClassifier')
plt.show()


plt.figure(figsize=(80,50))
tree.plot_tree(DT,filled=True,fontsize=100,max_depth=2)

metrics.plot_roc_curve(DT,X_test,y_test)
plt.title('DecisionTreeClassifier')
plt.show()
# Out:
# DecisionTreeClassifier Training Score:
#  100.0
# DecisionTreeClassifier Test Score:
#  87.92
# Confusion Matrix:
#  [[89 20]
#  [ 5 93]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.95      0.82      0.88       109
#            2       0.82      0.95      0.88        98
#
#     accuracy                           0.88       207
#    macro avg       0.88      0.88      0.88       207
# weighted avg       0.89      0.88      0.88       207
#
# Accuracy  87.92270531400966

# %% [markdown]
# # KNeighborsClassifier

# %%
import seaborn as sb
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 8)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)

#prediction
knn_pred =knn.predict(X_test)

knn_score = round(knn.score(X_train, y_train) * 100, 2)
knn_score_test = round(knn.score(X_test, y_test) * 100, 2)

print('KNeighborsClassifier Training Score: \n', knn_score)
print('KNeighborsClassifier Test Score: \n', knn_score_test)
print("Accuracy:", accuracy_score(y_test, knn_pred)*100)
print('Confusion Matrix: \n', confusion_matrix(y_test,knn_pred))
print('Classification Report: \n', classification_report(y_test,knn_pred))

print(confusion_matrix(y_test, knn_pred))
#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(knn_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('KNN')
plt.show()

metrics.plot_roc_curve(knn,X_test,y_test)
plt.title('KNN')
plt.show()
# Out:
# KNeighborsClassifier Training Score:
#  77.29
# KNeighborsClassifier Test Score:
#  67.63
# Accuracy: 67.6328502415459
# Confusion Matrix:
#  [[72 37]
#  [30 68]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.71      0.66      0.68       109
#            2       0.65      0.69      0.67        98
#
#     accuracy                           0.68       207
#    macro avg       0.68      0.68      0.68       207
# weighted avg       0.68      0.68      0.68       207
#
# [[72 37]
#  [30 68]]

# %% [markdown]
# # SVM Classifier

# %%
from sklearn.svm import SVC

# %%
pr= SVC(gamma='auto')
pr.fit(X_train, y_train)
pr_pred = pr.predict(X_test)

pr_score = round(pr.score(X_train, y_train) * 100, 2)
pr_score_test = round(pr.score(X_test, y_test) * 100, 2)


print('SVM Classifier Training Score: \n', pr_score)
print('SVM Classifier Test Score: \n', pr_score_test)
print("Accuracy: \n", accuracy_score(y_test, pr_pred)*100)
print('Confusion Matrix: \n', confusion_matrix(y_test,pr_pred))
print('Classification Report: \n', classification_report(y_test,pr_pred))
print(confusion_matrix(y_test, pr_pred))

#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(pr_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('svm Classifier')
plt.show()
metrics.plot_roc_curve(pr,X_test,y_test)
plt.title('svm Classifier')
plt.show()
# Out:
# SVM Classifier Training Score:
#  100.0
# SVM Classifier Test Score:
#  93.24
# Accuracy:
#  93.23671497584542
# Confusion Matrix:
#  [[107   2]
#  [ 12  86]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.90      0.98      0.94       109
#            2       0.98      0.88      0.92        98
#
#     accuracy                           0.93       207
#    macro avg       0.94      0.93      0.93       207
# weighted avg       0.94      0.93      0.93       207
#
# [[107   2]
#  [ 12  86]]

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random=RandomForestClassifier()
random.fit(X_train, y_train)
random_pred = random.predict(X_test)

random_score = round(random.score(X_train, y_train) * 100, 2)
random_score_test = round(random.score(X_test, y_test) * 100, 2)

print('RandomForestClassifier Training Score: \n', pr_score)
print('RandomForestClassifier Test Score: \n', pr_score_test)
print("Accuracy:", accuracy_score(y_test, random_pred)*100, )
print('Confusion Matrix: \n', confusion_matrix(y_test,random_pred))
print('Classification Report: \n', classification_report(y_test,random_pred))
#Plot the confusion matrix
sns.set(font_scale=1.5)
cm = confusion_matrix(random_pred, y_test)
sns.heatmap(cm, annot=True, fmt='g')
plt.title('RandomForestClassifier')
plt.show()
metrics.plot_roc_curve(random,X_test,y_test)
plt.title('RandomForestClassifier')
plt.show()
# Out:
# RandomForestClassifier Training Score:
#  100.0
# RandomForestClassifier Test Score:
#  93.24
# Accuracy: 87.92270531400966
# Confusion Matrix:
#  [[86 23]
#  [ 2 96]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.98      0.79      0.87       109
#            2       0.81      0.98      0.88        98
#
#     accuracy                           0.88       207
#    macro avg       0.89      0.88      0.88       207
# weighted avg       0.90      0.88      0.88       207
